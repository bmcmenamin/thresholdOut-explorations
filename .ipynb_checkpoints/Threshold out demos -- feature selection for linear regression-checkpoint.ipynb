# %% [markdown]
# ## Testing thresholdout with linear regression

# %% [markdown]
# This demo can use threshold out on linear regression or logistic regression models to replicate a more typical supervised learning context.
#
# Unfortunately, at the moment I'm still trying to come up with a method that uses a holdout set for feature selection that results in overfitting the training set *and* the holdout set. Until I can get good overfitting using traditional methods, it doesn't make sense to do thresholdout...

# %%
# %matplotlib nbagg

# %%
import thresholdOut_mydemo_featureSelection as my_demo

from importlib import reload
reload(my_demo)
# Out:
# <module 'thresholdOut_mydemo_featureSelection' from '/Users/mcmenamin/GitHub/thresholdOut/thresholdOut_mydemo_featureSelection.py'>

# %%
reps = 100
n, d = 100, 10000
krange = list(range(1, 30))

f = my_demo.runExpt_and_makePlots(n, d, krange, reps, is_classification=True);
# Out:
# ...
# 100%|██████████| 100/100 [00:42<00:00,  1.85it/s]
# <img src="data:image/png;base64,..." width="800">

# %%
f.set_figheight(10)
f.set_figwidth(8)
f
# Out:
# <img src="data:image/png;base64,..." width="800">
